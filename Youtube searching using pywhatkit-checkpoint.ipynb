# %%
import pywhatkit as pk 

def main():
    video = input("search :")
    pk.playonyt(video)
try:
    main()
except:
    print("Sorry an error occurred")
finally:
    print("Script closed")
# Out:
# search :ncs firefly
# Script closed
